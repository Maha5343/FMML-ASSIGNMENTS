# %% [markdown]
# <a href="https://colab.research.google.com/github/Maha5343/FMML-ASSIGNMENTS/blob/main/MODULE_8_LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 08:36:03--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   186MB/s    in 0.4s
#
# 2023-05-05 08:36:04 (186 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 24917   1412.7957v1  Object detection is an important research area...    cs
# 26218  1609.03279v2  This paper addresses the problem of face recog...    cs
# 18539   1105.5449v1  This paper introduces AntNet, a novel approach...    cs
# 20137   1411.1080v1  In this paper we present a greedy algorithm fo...    cs
# 18142  cs/0407037v1  Generalized evolutionary algorithm based on Ts...    cs
# ...             ...                                                ...   ...
# 22406  1606.00813v1  We present a novel k-way high-dimensional grap...  stat
# 7807   1803.05045v1  Generative adversarial networks are used to ge...  stat
# 26836  1611.10080v1  The trend towards increasingly deep neural net...    cs
# 6653   1704.08067v1  Within machine learning, the supervised learni...  stat
# 38995  1503.00843v1  The Digital Forgeries though not visibly ident...    cs
#
#                                                    title  year  \
# 24917  Detect2Rank : Combining Object Detectors Using...  2014
# 26218  Semi-Supervised Sparse Representation Based Cl...  2016
# 18539  AntNet: Distributed Stigmergetic Control for C...  2011
# 20137  A Heuristic Method for Solving the Problem of ...  2014
# 18142  Generalized Evolutionary Algorithm based on Ts...  2004
# ...                                                  ...   ...
# 22406  Generalized Root Models: Beyond Pairwise Graph...  2016
# 7807       Analysis of Nonautonomous Adversarial Systems  2018
# 26836  Wider or Deeper: Revisiting the ResNet Model f...  2016
# 6653   Exploiting random projections and sparsity wit...  2017
# 38995                A Survey On Video Forgery Detection  2015
#
#                                                 keywords
# 24917  [detection, important, detection, algorithms, ...
# 26218  [addresses, recognition, recognize, typically,...
# 18539  [introduces, communications, distributed, opti...
# 20137  [algorithm, partitioning, reasonable, algorith...
# 18142  [generalized, evolutionary, algorithm, canonic...
# ...                                                  ...
# 22406  [dimensional, graphical, generalized, explicit...
# 7807   [generative, adversarial, convergence, propert...
# 26836  [increasingly, observation, increasing, increa...
# 6653   [supervised, relationship, observations, chara...
# 38995  [forgeries, identifiable, perception, underlyi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 24917    [detection, important, detection, algorithms, ...
# 26218    [addresses, recognition, recognize, typically,...
# 18539    [introduces, communications, distributed, opti...
# 20137    [algorithm, partitioning, reasonable, algorith...
# 18142    [generalized, evolutionary, algorithm, canonic...
#                                ...
# 31381    [important, distribution, imbalanced, difficul...
# 9995     [classifier, synthesis, construct, artificial,...
# 38768    [continuum, associated, magnetogram, complexit...
# 6004     [textitcombinatorial, exploration, stochastic,...
# 31513    [meaningful, detection, expression, prediction...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8769 words.
# Out of those 4525 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="28534e86-1c0a-49c7-b83e-8e35bc13af09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28534e86-1c0a-49c7-b83e-8e35bc13af09")) {                    Plotly.newPlot(                        "28534e86-1c0a-49c7-b83e-8e35bc13af09",                        [{"x":["combining","universal","important","experiments","framework","detectors","considered","subsequent","consequence","algorithms","detection","significantly","contextual","assumptions","correlation","conditions","algorithm","appearance","outperforms","classification","dictionary","dictionaries","databases","recognize","variation","prototype","recognition","demonstrate","characterize","variables","representing","different","performance","addresses","insufficient","variations","unlabeled","expression","represented","typically","estimated","corrupted","supervised","representation","consisting","distributions","superiority","increasing","optimization","communications","realistic","stigmergy","encouraging","characteristics","collected","competitors","distributed","concurrently","evaluated","information","artificial","introduces","experimental","paradigmatic","communication","asynchronous","dependent","procedure","properties","functions","heuristics","correction","relatively","solutions","exploring","computationally","reasonable","partitioning","corresponding","inexpensive","heuristic","generated","configurations","statistics","distribution","evolutionary","outperform","appropriate","simulation","extensive","generalized","generalization","boltzmann","selection","canonical","measurements","efficient","particular","establish","decreasing","posterior","sketching","sequential","eigenvalues","directions","additional","precision","eigenvectors","initialization","mismatched","covariance","indicated","processes","respectively","observation","monitoring","temperature","validation","allocation","conducted","scheduling","estimation","estimates","management","performed","meteorological","correlations","reference","introduce","stochastic","infinitesimal","approximation","parameterized","illustrated","formalized","effectiveness","perturbation","electronically","approximate","simulations","partially","classically","developped","stationary","optimality","statistical","characterizing","specification","characterization","analyzing","simplified","formulation","particularly","comparisons","maximization","including","alternative","discrimination","heterogeneity","potentially","simulated","maximizing","regression","homogeneous","integrates","functional","expectation","explicitly","decomposed","approaches","polynomial","discriminant","parameters","likelihood","presenting","dedicated","component","extension","relationship","structure","multilinear","sequences","dimension","efficiently","principal","tensorial","introduced","numerical","challenging","probabilistic","computational","completion","pathologists","collaboration","extremely","dermoscopy","efficiency","segmentation","frameworks","simultaneously"],"y":[98,35,324,612,540,37,135,30,20,598,352,264,54,68,83,149,790,80,283,497,56,29,67,45,43,26,393,563,33,144,66,741,851,61,15,78,50,49,90,107,62,17,191,365,46,138,36,107,317,13,64,4,24,83,76,6,110,8,150,680,138,66,392,2,62,15,73,120,195,222,33,22,62,152,34,79,34,16,129,6,63,176,19,58,224,58,94,75,73,153,68,117,19,154,22,56,408,286,44,7,51,1,71,4,45,95,72,7,23,4,26,8,113,84,54,40,6,57,29,74,15,234,67,60,116,3,22,56,304,129,1,128,25,18,11,214,10,2,114,44,48,2,2,28,17,173,16,21,23,68,15,73,89,28,27,240,95,14,8,48,58,33,119,19,24,33,30,62,11,451,59,16,240,68,19,14,107,72,83,340,5,118,73,167,43,3,134,73,250,155,270,36,4,5,35,3,137,212,31,100],"type":"bar"},{"x":["combining","universal","important","experiments","framewor ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4525,), (4525, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Word</span> <span style=''>Entity</span> <span style=''>Duet</span> <span style='background-color:rgba(0, 255, 0, 0.3492537313432837);'>Representations</span> <span style=''>for</span> <span style=''>Document</span> <span style=''>Ranking</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>word</span> <span style=''>entity</span> <span style=''>duet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.43333333333333335);'>utilizing</span> <span style='background-color:rgba(0, 255, 0, 0.3794466403162055);'>knowledge</span> <span style=''>bases</span> <span style=''>in</span> <span style=''>ad</span> <span style=''>hoc</span> <span style='background-color:rgba(0, 255, 0, 0.6451612903225807);'>retrieval</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>the</span> <span style=''>query</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5045871559633028);'>documents</span> <span style=''>are</span> <span style=''>modeled</span> <span style=''>by</span> <span style=''>word</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3492537313432837);'>representations</span> <span style=''>and</span> <span style=''>entity</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3492537313432837);'>representations</span> <span style=''>Ranking</span> <span style=''>features</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>between</span> <span style=''>the</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3492537313432837);'>representations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>from</span> <span style=''>the</span> <span style=''>word</span> <span style=''>space</span> <span style=''>the</span> <span style=''>entity</span> <span style=''>space</span> <span style=''>and</span> <span style=''>the</span> <span style=''>cross</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connections</span> <span style=''>through</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3794466403162055);'>knowledge</span> <span style=''>graph</span> <span style=''>To</span> <span style=''>handle</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainties</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3103448275862069);'>automatically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructed</span> <span style=''>entity</span> <span style='background-color:rgba(0, 255, 0, 0.3492537313432837);'>representations</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.37190082644628103);'>attention</span> <span style=''>based</span> <span style=''>ranking</span> <span style=''>model</span> <span style=''>AttR</span> <span style=''>Duet</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>With</span> <span style=''>back</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style=''>from</span> <span style=''>ranking</span> <span style=''>labels</span> <span style=''>the</span> <span style=''>model</span> <span style=''>learns</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>how</span> <span style=''>to</span> <span style=''>demote</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Composite</span> <span style=''>Quantile</span> <span style=''>Fourier</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>for</span> <span style=''>Multi</span> <span style=''>Horizon</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Forecasting</span> <br/><br/><span style=''>A</span> <span style=''>novel</span> <span style=''>quantile</span> <span style=''>Fourier</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>are</span> <span style=''>provided</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>composite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantiles</span> <span style=''>using</span> <span style=''>time</span> <span style=''>as</span> <span style=''>the</span> <span style=''>only</span> <span style=''>input</span> <span style=''>to</span> <span style=''>the</span> <span style=''>model</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>is</span> <span style=''>a</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extrapolation</span> <span style=''>based</span> <span style=''>quantile</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>applied</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Empirical</span> <span style=''>results</span> <span style=''>showcase</span> <span style=''>that</span> <span style=''>for</span> <span style=''>time</span> <span style=''>series</span> <span style=''>data</span> <span style=''>that</span> <span style=''>have</span> <span style=''>clear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>seasonality</span> <span style=''>and</span> <span style=''>trend</span> <span style=''>the</span> <span style=''>model</span> <span style=''>provides</span> <span style=''>high</span> <span style=''>quality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>This</span> <span style=''>work</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>new</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>of</span> <span style=''>using</span> <span style=''>only</span> <span style=''>time</span> <span style=''>as</span> <span style=''>the</span> <span style=''>input</span> <span style=''>versus</span> <span style=''>using</span> <span style=''>past</span> <span style=''>data</span> <span style=''>such</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Extrapolation</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>has</span> <span style=''>not</span> <span style=''>been</span> <span style=''>studied</span> <span style=''>before</span> <span style=''>for</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style=''>KLMS</span> <span style=''>and</span> <span style=''>KRLS</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>A</span> <span style=''>Random</span> <span style=''>Fourier</span> <span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Perspective</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>online</span> <span style=''>Least</span> <span style=''>Squares</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.36196319018404904);'>nonlinear</span> <span style=''>modeling</span> <span style=''>in</span> <span style=''>RKH</span> <span style=''>spaces</span> <span style=''>(RKHS)</span> <span style=''>Instead</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implicitly</span> <span style=''>mapping</span> <span style=''>the</span> <span style=''>data</span> <span style=''>to</span> <span style=''>a</span> <span style=''>RKHS</span> <span style=''>(eg</span> <span style=''>kernel</span> <span style=''>trick)</span> <span style=''>we</span> <span style=''>map</span> <span style=''>the</span> <span style=''>data</span> <span style=''>to</span> <span style=''>a</span> <span style=''>finite</span> <span style='background-color:rgba(255, 0, 0, 0.3865698729582577);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Euclidean</span> <span style=''>space</span> <span style=''>using</span> <span style=''>random</span> <span style=''>features</span> <span style=''>of</span> <span style=''>the</span> <span style=''>kernels</span> <span style=''>Fourier</span> <span style='background-color:rgba(0, 255, 0, 0.3953488372093023);'>transform</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantage</span> <span style=''>is</span> <span style=''>that</span> <span style=''>the</span> <span style=''>inner</span> <span style=''>product</span> <span style=''>of</span> <span style=''>the</span> <span style=''>mapped</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.30434782608695665);'>approximates</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>function</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>does</span> <span style=''>not</span> <span style=''>require</span> <span style=''>any</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sparsification</span> <span style=''>since</span> <span style=''>in</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>all</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>size</span> <span style=''>remains</span> <span style=''>fixed</span> <span style=''>and</span> <span style=''>does</span> <span style=''>not</span> <span style=''>increase</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>steps</span> <span style=''>As</span> <span style=''>a</span> <span style=''>result</span> <span style=''>the</span> <span style=''>obtained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.36032388663967607);'>computationally</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contrasting</span> <span style=''>for</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>marked</span> <span style=''>their</span> <span style=''>place</span> <span style=''>over</span> <span style=''>the</span> <span style=''>last</span> <span style=''>few</span> <span style=''>years</span> <span style=''>as</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performing</span> <span style=''>model</span> <span style=''>for</span> <span style=''>various</span> <span style=''>visual</span> <span style=''>tasks</span> <span style=''>They</span> <span style=''>are</span> <span style=''>however</span> <span style=''>most</span> <span style=''>suited</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>from</span> <span style=''>large</span> <span style=''>amounts</span> <span style=''>of</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>Previous</span> <span style=''>attempts</span> <span style=''>have</span> <span style=''>been</span> <span style=''>made</span> <span style=''>to</span> <span style=''>use</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>by</span> <span style=''>applying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>These</span> <span style=''>attempts</span> <span style=''>require</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>and</span> <span style=''>training</span> <span style=''>methods</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>training</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>networks</span> <span style=''>that</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contrasting</span> <span style=''>between</span> <span style=''>spatial</span> <span style=''>regions</span> <span style=''>within</span> <span style=''>images</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>can</span> <span style=''>be</span> <span style=''>employed</span> <span style=''>within</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>trained</span> <span style=''>using</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>such</span> <span style=''>as</span> <span style=''>SGD</span> <span style=''>and</span> <span style=''>back</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <span style=''>thus</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complementing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supe ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.24355300859598855)
# 	architecture (0.0913323782234957)
# 	processing (0.1085243553008596)
# 	representation (0.13073065902578795)
# 	experimental (0.14040114613180515)
# 	segmentation (0.07593123209169055)
# 	detection (0.12607449856733524)
# 	different (0.26540114613180515)
# 	convolutional (0.12822349570200572)
# 	recognition (0.1407593123209169)
#
# Some Statistics words are:
# 	variables (0.13645418326693226)
# 	estimation (0.17031872509960158)
# 	stochastic (0.13745019920318724)
# 	statistical (0.15587649402390438)
# 	theoretical (0.15139442231075698)
# 	distribution (0.18774900398406374)
# 	algorithm (0.39193227091633465)
# 	inference (0.20019920318725098)
# 	dimensional (0.1902390438247012)
# 	regression (0.17280876494023906)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8af80562-d5b3-4f46-b178-a791f75e8d21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8af80562-d5b3-4f46-b178-a791f75e8d21")) {                    Plotly.newPlot(                        "8af80562-d5b3-4f46-b178-a791f75e8d21",                        [{"x":["combining","universal","important","experiments","framework","detectors","considered","subsequent","consequence","algorithms","detection","significantly","contextual","assumptions","correlation","conditions","algorithm","appearance","outperforms","classification","dictionary","dictionaries","databases","recognize","variation","prototype","recognition","demonstrate","characterize","variables","representing","different","performance","addresses","insufficient","variations","unlabeled","expression","represented","typically","estimated","corrupted","supervised","representation","consisting","distributions","superiority","increasing","optimization","communications","realistic","stigmergy","encouraging","characteristics","collected","competitors","distributed","concurrently","evaluated","information","artificial","introduces","experimental","paradigmatic","communication","asynchronous","dependent","procedure","properties","functions","heuristics","correction","relatively","solutions","exploring","computationally","reasonable","partitioning","corresponding","inexpensive","heuristic","generated","configurations","statistics","distribution","evolutionary","outperform","appropriate","simulation","extensive","generalized","generalization","boltzmann","selection","canonical","measurements","efficient","particular","establish","decreasing","posterior","sketching","sequential","eigenvalues","directions","additional","precision","eigenvectors","initialization","mismatched","covariance","indicated","processes","respectively","observation","monitoring","temperature","validation","allocation","conducted","scheduling","estimation","estimates","management","performed","meteorological","correlations","reference","introduce","stochastic","infinitesimal","approximation","parameterized","illustrated","formalized","effectiveness","perturbation","electronically","approximate","simulations","partially","classically","developped","stationary","optimality","statistical","characterizing","specification","characterization","analyzing","simplified","formulation","particularly","comparisons","maximization","including","alternative","discrimination","heterogeneity","potentially","simulated","maximizing","regression","homogeneous","integrates","functional","expectation","explicitly","decomposed","approaches","polynomial","discriminant","parameters","likelihood","presenting","dedicated","component","extension","relationship","structure","multilinear","sequences","dimension","efficiently","principal","tensorial","introduced","numerical","challenging","probabilistic","computational","completion","pathologists","collaboration","extremely","dermoscopy","efficiency","segmentation","frameworks","simultaneously","dermoscopic","developed","international","challenge","extraction","convolutional","automatic","announced","increases","following","similarity","promising","calculating","accuracies","calculation","explanation","operating","backpropagation","developing","demanding","rectified","highlights","clustering","implements","rectification","interpret","principle","ingredients","afterwards","traditional","transform","reversing","assumption","objective","adversarial","generator","asymptotic","representations","collapsing","synthetic","generative","interpreted","consistency","variational","specifying","complicated","manifolds","guarantee","autoencoder","difficult","connectivity","unsupervised","scattering","mathematical","invari ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	reversing
# 	correntropy
# 	tempering
# 	unobservable
# 	psychiatric
# 	multipartite
# 	reassignment
# 	reconstructive
# 	illustrations
# 	amortization
# 	uncollapsed
# 	similitude
# 	appropriateness
# 	oblivious
# 	transcriptional
# 	heteroskedastic
# 	clarified
# 	exploding
# 	overconfident
# 	unregularized
# Some words which never appear in Statistics papers:
# 	stigmergy
# 	concurrently
# 	paradigmatic
# 	electronically
# 	classically
# 	developped
# 	tensorial
# 	pathologists
# 	dermoscopy
# 	cityscapes
# 	monolingual
# 	inheritance
# 	nonmonotonic
# 	attentional
# 	monocular
# 	ultrasound
# 	syntactic
# 	concatenating
# 	infrequent
# 	appearances

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.082139004469102e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7625
